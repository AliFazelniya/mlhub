# %%
from scipy.stats import poisson
print(poisson.pmf(16, 12))
# Out:
# 0.0542933401099789

# %%
print(poisson.cdf(16, 12))
# Out:
# 0.8987089925601621

# %%
print(1 - poisson.cdf(16, 12))
# Out:
# 0.10129100743983788

# %%
import numpy as np
data_poi = np.random.poisson(12, 1000)
data_poi[0:50]
# Out:
# array([16,  7, 15, 12,  9, 13, 11, 13, 20, 17, 13, 14, 18,  9, 19, 12, 14,
#        15, 11, 13, 14, 10, 12, 10, 18, 14,  8, 14, 11,  9, 10, 14, 15, 10,
#         8, 10, 13,  7, 14, 10, 11, 20, 16, 13, 13, 12, 11, 16,  4, 15],
#       dtype=int32)

# %%
import matplotlib.pyplot as plt
plt.hist(data_poi, bins = range(min(data_poi), max(data_poi + 1), 1), edgecolor="black")
plt.show()
