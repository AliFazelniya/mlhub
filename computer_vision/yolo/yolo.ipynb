# %%
from ultralytics import YOLO

model = YOLO("yolo26n.pt")
results = model("data/images/crowd.jpg", save = True)
# Out:
# image 1/1 /home/norbert/Projects/ml/computer_vision/yolo/data/images/crowd.jpg: 640x384 21 persons, 9.2ms
# Speed: 31.6ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /home/norbert/Projects/ml/computer_vision/yolo/runs/detect/predict-2
