# %%
from ultralytics import YOLO

model = YOLO("yolo26n.pt")
results = model("data/crowd.jpg", save = True)
# Out:
# ...
#
# image 1/1 /home/norbert/Projects/ml/computer_vision/crowd.jpg: 640x384 21 persons, 11.0ms
# Speed: 32.9ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /home/norbert/Projects/ml/computer_vision/runs/detect/predict
