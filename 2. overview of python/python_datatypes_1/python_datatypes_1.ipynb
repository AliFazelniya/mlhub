# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#     مروری بر داده‌ساختارها (۱)
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> (List) لیست
#     </font>
# </h2>

# %%
myList = [10, 20, 30]
myList
# Out:
# [10, 20, 30]

# %%
zeros = [0] * 100
#یک لیست به طول 100

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> دسترسی به مقادیر لیست
#     </font>
# </h2>

# %%
myList = [10, 20, 30]
myList
# Out:
# [10, 20, 30]

# %%
myList[:]
# Out:
# [10, 20, 30]

# %%
myList[1]
# Out:
# 20

# %%
myList[1:]
# Out:
# [20, 30]

# %%
myList[1:0]
# Out:
# []

# %%
myList[0:2]
# Out:
# [10, 20]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> تغییر مقادیر لیست
#     </font>
# </h2>

# %%
num = [10, 20, 30]
num[0] = 1
num
# Out:
# [1, 20, 30]

# %%
num[0:3] = [1, 2, 3]
num
# Out:
# [1, 2, 3]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> ارجاعی بودن لیست
#     </font>
# </h2>

# %%
main = [1, 2, 3]
ref = main
ref
# Out:
# [1, 2, 3]

# %%
[1, 2, 3]
main[0] = 10
ref
# Out:
# [10, 2, 3]

# %%
ref[0] = 1
main
# Out:
# [1, 2, 3]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> (Tuple) چندتایی
#     </font>
# </h2>

# %%
t = ("ali", 123, 2.5)
t
# Out:
# ('ali', 123, 2.5)

# %%
type(t)
# Out:
# tuple

# %%
t = ("ali", 123, 2.5)
t[0]
# Out:
# 'ali'

# %%
t[0:2]
# Out:
# ('ali', 123)

# %%
for it in t:
   print(it)
# Out:
# ali
# 123
# 2.5

# %%
t = "ali", 123, 2.5
t
# Out:
# ('ali', 123, 2.5)

# %%
type(t)
# Out:
# tuple

# %%
a, b, c = 10, 20, 30
print(a, b, c)
# Out:
# 10 20 30

# %%
a, b = b, a
print(a, b)
# Out:
# 20 10

# %%
t = ()
len(t)
# Out:
# 0

# %%
type(t)
# Out:
# tuple

# %%
t = (1)
type(t)
# Out:
# int

# %%
t = 1,
len(t)
# Out:
# 1

# %%
type(t)
# Out:
# tuple

# %%
myList = [1, 2]
def f():
    return myList
a = f()
a.append("12")
myList
# Out:
# [1, 2, '12']

# %%
a[0] = 10
myList
# Out:
# [10, 2, '12']

# %%
myTuple = 1, 2
def f():
     return myTuple
a = f()
a
# Out:
# (1, 2)

# %%
a[0] = 10
# 'tuple' object does not support item assignment خطا می‌دهد
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = 3, 4
myTuple
# Out:
# (1, 2)
