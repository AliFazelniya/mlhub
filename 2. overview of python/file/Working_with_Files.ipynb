# %%
file = open('example.txt', 'r')
file.close()

# %%
with open('example.txt', 'r') as file:
    pass

# %%
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello, World!
# Hi, Python.

# %%
with open('example.txt', 'r') as file:
    line = file.readline()
    while line:
        print(line, end='')
        line = file.readline()
# Out:
# Hello, World!
# Hi, Python.

# %%
with open('example.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        print(line, end='')
# Out:
# Hello, World!
# Hi, Python.

# %%
with open('example.txt', 'w') as file:
    file.write("Hello, World!\n")
    file.write("This is a new line.\n")

# %%
with open('example.txt', 'a') as file:
    file.write("Appending this line.\n")

# %%
try:
    with open('missing_example.txt', 'r') as file:
        content = file.read()
except FileNotFoundError:
    print("File not found.")
except IOError:
    print("Error reading file.")
# Out:
# File not found.
