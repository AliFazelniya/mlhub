# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#     مروری بر داده‌ساختارها (۲)
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> (Set) مجموعه
#     </font>
# </h2>

# %%
type(set())
# Out:
# set

# %%
st = {2, 3, 1}
st
# Out:
# {1, 2, 3}

# %%
len(st)
# Out:
# 3

# %%
type(st)
# Out:
# set

# %%
st = {}
type(st)
# Out:
# dict

# %%
names = set()
names.add('ali')
names.add('mohamadreza')
names.add('amir')
names.add('amir')
names
# Out:
# {'ali', 'amir', 'mohamadreza'}

# %%
nums = set()
nums.add(1)
nums.add(2)
nums.add(3)
1 in nums
# Out:
# True

# %%
4 in nums
# Out:
# False

# %%
a = {1, 2, 3}
a.remove(1)
a.discard(2)
a
# Out:
# {3}

# %%
a.discard(4)
a.remove(4)
# KeyError: 4 خطا می‌دهد
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 a.discard(4)
# ----> 2 a.remove(4)
#       3 # KeyError: 4 خطا می‌دهد
#
# KeyError: 4

# %%
a = {1, 2, 3}
b = {3, 2, 4}
a.intersection(b)
# Out:
# {2, 3}

# %%
b.intersection(a)
# Out:
# {2, 3}

# %%
a & b
# Out:
# {2, 3}

# %%
b.union(a)
# Out:
# {1, 2, 3, 4}

# %%
a | b
# Out:
# {1, 2, 3, 4}

# %%
a = {1, 2, 3}
b = {3, 2, 4}
a.difference(b)
# Out:
# {1}

# %%
b - a
# Out:
# {4}

# %%
a ^ b
# Out:
# {1, 4}

# %%
b.symmetric_difference(a)
# Out:
# {1, 4}

# %%
a = set("salam")
b = set("varam")
{x for x in a if x not in b}
# Out:
# {'l', 's'}

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc"> (Dictionary) لغت‌نامه
#     </font>
# </h2>

# %%
d = {"ali": 12, "amir": 2.3}
d
# Out:
# {'ali': 12, 'amir': 2.3}

# %%
d['ali']
# Out:
# 12

# %%
d['ali'] = 23
d
# Out:
# {'ali': 23, 'amir': 2.3}

# %%
list(d)
# Out:
# ['ali', 'amir']

# %%
dict()
# Out:
# {}

# %%
dict([("ali", 12), ("amir", 2.3)])
# Out:
# {'ali': 12, 'amir': 2.3}

# %%
age = {'mohamadreza':17}
age['ali'] = 22
age['mohamadreza'] = 18
age
# Out:
# {'mohamadreza': 18, 'ali': 22}

# %%
square = {1: 1, 2: 4, 3: 9, 4: 16}
3 in square
# Out:
# True

# %%
square[3]
# Out:
# 9

# %%
5 in square
# Out:
# False

# %%
square[5]
# KeyError: 5 خطا می‌دهد
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 square[5]
#
# KeyError: 5

# %%
square = {1: 1, 2: 4, 3: 9, 4: 16}
square.pop(3)
# Out:
# 9

# %%
del square[1]
square
# Out:
# {2: 4, 4: 16}

# %%
square.pop(5)
# KeyError: 5 خطا می‌دهد
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 square.pop(5)
#
# KeyError: 5

# %%
grade = {'mamad': 20, 'ali':19, 'pooyan':19}
grade.get('ali')
# Out:
# 19

# %%
grade['mahdi'] = grade.get('mahdi', 19) + 1 
grade.get('mahdi')
# Out:
# 20

# %%
age = {'ali': 21, 'mmdreza': 18, 'mahdi': 22, 'pooyan':25}
type(age.values())
# Out:
# dict_values

# %%
type(age.keys())
# Out:
# dict_keys

# %%
age.values()
# Out:
# dict_values([21, 18, 22, 25])

# %%
list(age.values())
# Out:
# [21, 18, 22, 25]

# %%
{x:x*x for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
dict(ali=12, amir=2.3)
# Out:
# {'ali': 12, 'amir': 2.3}

# %%
my_dict = {'ali': 'A', 'amir': 'B'}
for k, v in my_dict.items():
    print(k + " got " + v)
# Out:
# ali got A
# amir got B
