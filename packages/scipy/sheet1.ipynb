# %%
from scipy import stats
import numpy as np
from scipy.stats import uniform
from scipy.stats import ttest_1samp
from scipy.stats import norm

# %%
data = uniform.rvs(size=10)
print("random data : ", data)
# Out:
# random data :  [0.92995236 0.74901396 0.22834117 0.8916016  0.32128816 0.90469857
#  0.83306662 0.65458334 0.73458541 0.3837937 ]

# %%
data = [2, 4, 6, 8, 10]
mean = np.mean(data)
std = np.std(data)
print("mean", mean)
print("std : ", std)
# Out:
# mean 6.0
# std :  2.8284271247461903

# %%
data = [5, 7, 8, 6, 9]
t_stat, p_value = ttest_1samp(data, 7)
print("p value :", p_value)
# Out:
# p value : 1.0

# %%
data = norm.rvs(size=10, loc=5, scale=2) 
print("data :", data)
# Out:
# data : [5.6300096  8.10492525 2.1430943  8.96147305 7.56661749 3.56233446
#  5.03033553 4.65668773 5.89777459 6.21519296]
